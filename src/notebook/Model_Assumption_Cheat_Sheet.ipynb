# %%
import pandas as pd

# %%
matrix = pd.read_csv('../../data/Expanded_Classification_Model_Assumptions_Matrix.csv')
matrix
# Out:
#                  Model                                        Assumptions  \
# 0  Logistic Regression  Linearity between independent variables and lo...
# 1              XGBoost  No assumptions about the data distribution; Wo...
# 2             LightGBM  No assumptions about data distribution; Handle...
# 3        Random Forest  No assumptions about data distribution; Handle...
#
#                           Preprocessing Requirements  \
# 0  Check for multicollinearity; One-hot encoding ...
# 1  One-hot encoding or target encoding for catego...
# 2  One-hot or target encoding for categorical var...
# 3  One-hot encoding for categorical variables; Ha...
#
#                                           Violations  \
# 0  Imbalanced data can lead to biased results; Ou...
# 1  Sensitive to high cardinality in categorical v...
# 2  Sensitive to noisy data; Imbalanced datasets m...
# 3  Imbalanced data may lead to biased results; Ca...
#
# ...
